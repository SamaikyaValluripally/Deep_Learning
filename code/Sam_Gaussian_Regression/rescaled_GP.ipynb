# %%
import xlsxwriter
import plotly.plotly as py
import matplotlib.pyplot as p
import plotly.graph_objs as go
import pandas as pd 
import numpy as np
import pylab 
import scipy.stats as stats
from numpy import *
import statsmodels.api as sm
S=pow(10, -5)
S2=pow(10, -1)
leven = []
dissim = []
counter = 0
###################################################################################################################
#first the datasets: bot_compiled and non_bot_compiled are to be merged nto a single matrix
is_bot=pd.read_excel('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/bot_scoring.xlsx').as_matrix()
non_bot=pd.read_excel('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/non_botscoring.xlsx').as_matrix()
bnb = np.concatenate((is_bot,non_bot))
print(bnb)
####################################################################################################################
####################################################################################################################
#write the whole file as an excel sheet and save the combined bot and non_bot data
workbook = xlsxwriter.Workbook('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/bnbv2r.xlsx')
worksheet = workbook.add_worksheet()
array = bnb
row = 0
col = 0
for uid,wdr,dissim,leven in (array):
    worksheet.write(row,col, uid)
    worksheet.write(row,col+1, wdr)
    worksheet.write(row,col+2, dissim)
    worksheet.write(row,col+3, leven)
    row+=1
workbook.close()
# Out:
# C:\Users\svbqb\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning:
#
# The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
# [['calmerthanyouare_' 0.00183979398134 0.945465525984513 43.277520814061]
#  ['ajones321' -0.00404812994024 0.33455366722422 24.0364389233954]
#  ['MAGICHUSTLE' 0.0017915455263 0.944170559002748 87.9101449275362]
#  ...
#  ['inasnowboundland' 0.000961384342189 0.974567439362273 436.087722772277]
#  ['rich-creamery-butter' 0.000571628053988 0.981660869592324
#   586.031287128712]
#  ['Re_Re_Think' 0.000610392839617 0.986546287025812 1051.84935830002]]

# %%
import xlsxwriter
import plotly.plotly as py
import matplotlib.pyplot as p
import plotly.graph_objs as go
import pandas as pd 
import numpy as np
import pylab 
import scipy.stats as stats
from numpy import *
import statsmodels.api as sm
S=pow(10, -5)
S2=pow(10, -1)
leven = []
dissim = []
counter = 0
###########################leven to wdr #############################################
lvn = np.genfromtxt("C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/bnb_leven.csv", delimiter=";", skip_header=1)
print(lvn)
stats.probplot(lvn, plot=pylab)
pylab.show()
for lvn in lvn:
    leven.append(lvn*S)
print(leven)        
print(max(leven))
print(min(leven))
stats.probplot(leven, plot=pylab)
pylab.show()
###########################dissim to wdr####################################################
dis = np.genfromtxt("C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/bnb_dissim.csv", delimiter=";", skip_header=1)
stats.probplot(dis, plot=pylab)
pylab.show()
for dis in dis:
    dissim.append(dis*S2)
print(dissim)        
print(max(dissim))
print(min(dissim))
workbook = xlsxwriter.Workbook('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/final.xlsx')
worksheet = workbook.add_worksheet()
array = dissim
row = 0
col = 0

for dissim in (array):
    #worksheet.write(row,col, uid)
    #worksheet.write(row,col+1, wdr)
    worksheet.write(row,col+2, dissim)
    #worksheet.write(row,col+3, leven)
    row+=1
workbook.close()
#stats.probplot(dissim, plot=pylab)
#pylab.show()
# Out:
# [  43.27752081   24.03643892   87.91014493 ...  436.0877228   586.0312871
#  1051.849358  ]
# ...

# %%
print(__doc__)
# Authors: Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>
#
# License: BSD 3 clause
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import pylab as pb
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF)
#from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
###################################################################################################33
#first the datasets: bot_compiled and non_bot_compiled are to be merged into a single matrix
is_bot=pd.read_excel('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/ML TASK/rescaled_bot.xlsx').as_matrix()
non_bot=pd.read_excel('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/ML TASK/rescaled_nonbot.xlsx').as_matrix()
X = np.concatenate((is_bot,non_bot))
y=X[:,[2]]
class_names = ['is_bot','non_bot']
x_train, x_test, y_train_labels, y_test_labels = train_test_split(X,y,test_size=0.33)
kernels = [1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))]
# Specify Gaussian Process
gp = GaussianProcessRegressor(kernel=kernel)
# Plot prior
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
y_mean = gp.predict(x_train)
plt.plot(x_train, y_mean, 'k', lw=3, zorder=9)
plt.title("Prior (kernel:  %s)" % kernel, fontsize=12)
gp.fit(x_train, y_train_labels)
# Plot posterior
plt.subplot(2, 1, 2)
#X_ = np.linspace(0, 5, 100)
y_mean = gp.predict(x_test)
plt.plot(x_test, y_mean, 'k', lw=3, zorder=9)
#plt.scatter(x_test, y_test_labels, c='r', s=50, zorder=10, edgecolors=(0, 0, 0))
plt.title("Posterior (kernel: %s)\n Log-Likelihood: %.3f" %(gp.kernel_, gp.log_marginal_likelihood(gp.kernel_.theta)))
plt.tight_layout()
plt.show()
# Out:
# Automatically created module for IPython interactive environment
# C:\Users\svbqb\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:457: UserWarning:
#
# fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 3.48750000e+01, -1.45199698e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 205, 'nit': 31, 'warnflag': 2}

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import itertools
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap
 
##np.random.seed(1)
##def f(x):
  ##  """The function to predict."""
   ## return x * np.sin(x)

# ----------------------------------------------------------------------
#  First the noiseless case
##X = np.atleast_2d([1., 3., 5., 6., 7., 8.]).T
###################################################################################################33
#first the datasets: bot_compiled and non_bot_compiled are to be merged into a single matrix
is_bot=pd.read_excel('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/ML TASK/rescaled_bot.xlsx').as_matrix()
non_bot=pd.read_excel('C:/Users/svbqb/Documents/Asst_NLP/bot_nonbot_scoring/ML TASK/rescaled_nonbot.xlsx').as_matrix()
X = np.concatenate((is_bot,non_bot))
y=X[:,[2]]
class_names = ['is_bot','non_bot']

##########################################################################################################
# Split our data
x_train, x_test, y_train_labels, y_test_labels = train_test_split(X,y,test_size=0.33)
# Observations
##y = f(X).ravel()
################################################################################################################
# Mesh the input space for evaluations of the real function, the prediction and
# its MSE
##x = np.atleast_2d(np.linspace(0, 10, 1000)).T
# Instanciate a Gaussian Process model
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(x_train, y_train_labels)

# Make the prediction on the meshed x-axis (ask for MSE as well)
##y_pred, sigma = gp.predict(x_test, return_std=True)
y_pred = gp.predict(x_test)
#print(y_pred)

plt.plot(X, y)
#pl.axis([-5, 5, -3, 3])
plt.title('plotted data')
plt.show()
fig = plt.figure()
plt.plot(X, y, 'r.', markersize=10, label=u'Observations')

plt.scatter(y_test_labels, y_pred)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

# Plot prior
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
y_mean = gp.predict(x_train)
####################################plt.plot(x_train, y_mean, 'k', lw=3, zorder=9)
plt.plot(x_train, y_mean, 'k')
plt.title("Prior (kernel:  %s)" % kernel, fontsize=12)
##gp.fit(x_train, y_train_labels)
# Plot posterior
plt.subplot(2, 1, 2)
#X_ = np.linspace(0, 5, 100)
##y_mean = gp.predict(x_test)
##plt.plot(x_test, y_mean, 'k', lw=3, zorder=9)
######################################3333plt.plot(x_test, y_pred, 'k', lw=3, zorder=9)
plt.plot(x_test, y_pred, 'k')
#plt.scatter(x_test, y_test_labels, c='r', s=50, zorder=10, edgecolors=(0, 0, 0))
plt.title("Posterior (kernel: %s)\n Log-Likelihood: %.3f" %(gp.kernel_, gp.log_marginal_likelihood(gp.kernel_.theta)))
plt.tight_layout()
plt.show()

#plt.scatter(X, y);
####plt.plot(X, y)
#pl.axis([-5, 5, -3, 3])
######################plt.title('plotted data')
#######plt.show()
#################################fig = plt.figure()
####################################plt.plot(x_test, f(x_test), 'r.', markersize=10, label=u'Observations')


###plt.plot(x_test, f(x_test))
###plt.title('graph')
###plt.plot(x_train, y_train_labels, 'r.', markersize=10, label=u'Observations')
###plt.plot(x_test, y_pred, 'b-', label=u'Prediction')
###plt.show()

# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
##fig = plt.figure()
##plt.plot(x_test, f(x_test), 'r:')#,# label=u'$f(x) = x\,\sin(x)$')
##plt.plot(x_train, y_train_labels, 'r.', markersize=10, label=u'Observations')
##plt.plot(x_test, y_pred, 'b-', label=u'Prediction')
##plt.fill(np.concatenate([x_test, x_test[::-1]]),
   ##      np.concatenate([y_pred - 1.9600 * sigma,
     ##                   (y_pred + 1.9600 * sigma)[::-1]]),
       ##  alpha=.5, fc='b', ec='None', label='95% confidence interval')
##plt.xlabel('$x_test$')
##plt.ylabel('$f(x_test)$')
##plt.ylim(-10, 20)
##plt.legend(loc='upper left')


#plotting confusion matrix
print(y_pred)
# Out:
# C:\Users\svbqb\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:457: UserWarning:
#
# fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([8.        , 0.51240376]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 52, 'nit': 8, 'warnflag': 2}
#
# C:\Users\svbqb\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:457: UserWarning:
#
# fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([44.5       , -0.88381571]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 62, 'nit': 6, 'warnflag': 2}
#
# C:\Users\svbqb\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:457: UserWarning:
#
# fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([45.        ,  3.19426381]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 66, 'nit': 8, 'warnflag': 2}
#
# C:\Users\svbqb\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:457: UserWarning:
#
# ...
